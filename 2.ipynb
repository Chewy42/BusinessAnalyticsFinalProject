# %%
import pandas as pd
import numpy as np
import json

# %%
def read_large_jsonl(file_path):
    data = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(pd.json_normalize(json.loads(line.strip())))
    return pd.concat(data, ignore_index=True)

df = read_large_jsonl("datasets/REGEN/clothing_sub.jsonl")
df.drop(columns=['reviewer_id'], inplace=True)
print(f"Shape: {df.shape}")
print(df.describe())
print(df.columns)
df.head()
# Out:
# Shape: (111792, 19)
#        metadata.example.richness  metadata.example.confidence  \
# count              111792.000000                111792.000000
# mean                    4.333459                     5.965785
# std                     1.020824                     1.119519
# min                     1.000000                     2.000000
# 25%                     3.000000                     5.000000
# 50%                     5.000000                     6.000000
# 75%                     5.000000                     7.000000
# max                     7.000000                     7.000000
#
#        metadata.last_purchase.veracity  metadata.last_purchase.grounding  \
# count                     111792.00000                     111792.000000
# mean                           5.76484                          5.087207
# std                            0.87389                          1.342804
# min                            1.00000                          1.000000
# 25%                            5.00000                          5.000000
# 50%                            6.00000                          5.000000
# 75%                            6.00000                          6.000000
# max                            7.00000                          7.000000
#
#        metadata.last_purchase.foresight  metadata.last_purchase.clarity  \
# count                     111792.000000                   111792.000000
# mean                           4.055648                        5.231662
# std                            1.680798                        0.672102
# min                            1.000000                        1.000000
# 25%                            3.000000                        5.000000
# 50%                            5.000000                        5.000000
# 75%                            5.000000                        5.000000
# max                            7.000000                        7.000000
#
#        metadata.last_purchase.personalization  \
# count                           111792.000000
# mean                                 5.277855
# std                                  1.139190
# min                                  1.000000
# 25%                                  5.000000
# 50%                                  5.000000
# 75%                                  6.000000
# max                                  7.000000
#
#        metadata.last_purchase.confidence  metadata.user.veracity  \
# count                      111792.000000           111792.000000
# mean                            4.543706                5.978702
# std                             0.718146                0.531300
# min                             2.000000                3.000000
# 25%                             4.000000                6.000000
# 50%                             5.000000                6.000000
# 75%                             5.000000                6.000000
# max                             7.000000                7.000000
#
#        metadata.user.grounding  metadata.user.clarity  \
# count            111792.000000          111792.000000
# mean                  5.766388               5.345213
# std                   0.780054               0.696579
# min                   3.000000               3.000000
# 25%                   5.000000               5.000000
# 50%                   6.000000               5.000000
# 75%                   6.000000               6.000000
# max                   7.000000               7.000000
#
#        metadata.user.personalization  metadata.user.confidence
# count                  111792.000000             111792.000000
# mean                        5.210561                  4.113335
# std                         0.673141                  0.655143
# min                         1.000000                  2.000000
# 25%                         5.000000                  4.000000
# 50%                         5.000000                  4.000000
# 75%                         5.000000                  4.000000
# max                         7.000000                  7.000000
# Index(['purchase_history', 'last_purchase.reason', 'last_purchase.explanation',
#        'user.profile', 'user.brief_summary', 'user.long_summary',
#        'metadata.example.richness', 'metadata.example.confidence',
#        'metadata.last_purchase.veracity', 'metadata.last_purchase.grounding',
#        'metadata.last_purchase.foresight', 'metadata.last_purchase.clarity',
#        'metadata.last_purchase.personalization',
#        'metadata.last_purchase.confidence', 'metadata.user.veracity',
#        'metadata.user.grounding', 'metadata.user.clarity',
#        'metadata.user.personalization', 'metadata.user.confidence'],
#       dtype='object')
#                                     purchase_history  \
# 0  [{'item': {'asin': 'B00NIXF4NO', 'title': 'Lif...
# 1  [{'item': {'asin': 'B008DVF0BC', 'title': 'Zum...
# 2  [{'item': {'asin': 'B00NWA56L8', 'title': 'Har...
# 3  [{'item': {'asin': 'B00VFGM1H8', 'title': 'Jer...
# 4  [{'item': {'asin': 'B000GYU3HU', 'title': 'Sca...
#
#                                 last_purchase.reason  \
# 0  The customer likely needed a comfortable, ligh...
# 1  Needed a comfortable and breathable athletic s...
# 2  The customer likely needed a new swimsuit for ...
# 3  Needed a new, well-made wallet that is slim an...
# 4  The customer likely wanted a durable and good ...
#
#                            last_purchase.explanation  \
# 0  The customer's positive review highlights the ...
# 1  The customer has a history of purchasing sanda...
# 2  The customer's purchase history reveals a pref...
# 3  The customer's purchase history shows a focus ...
# 4  The customer's review of the final purchase hi...
#
#                                         user.profile  \
# 0      Comfortable, Stylish, Value-conscious shopper
# 1               Comfortable shoe lover, active woman
# 2  Recreational, Comfortable, Casual, Active, Fas...
# 3             Practical, well-dressed, men's fashion
# 4              Male, Casual,  Footwear,  Unique Ring
#
#                                   user.brief_summary  \
# 0  This customer enjoys comfortable and stylish c...
# 1  The customer enjoys comfortable footwear and a...
# 2  The customer enjoys comfortable clothing and h...
# 3  This customer primarily purchases men's clothi...
# 4  This customer enjoys purchasing men's casual c...
#
#                                    user.long_summary  \
# 0  This customer demonstrates a clear preference ...
# 1  This customer demonstrates a preference for co...
# 2  This customer has a strong interest in comfort...
# 3  This customer demonstrates a clear preference ...
# 4  This customer's purchase history primarily cen...
#
#    metadata.example.richness  metadata.example.confidence  \
# 0                          5                            6
# 1                          5                            6
# 2                          5                            7
# 3                          3                            7
# 4                          3                            5
#
#    metadata.last_purchase.veracity  metadata.last_purchase.grounding  \
# 0                                6                                 6
# 1                                6                                 5
# 2                                4                                 3
# 3                                5                                 3
# 4                                6                                 6
#
#    metadata.last_purchase.foresight  metadata.last_purchase.clarity  \
# 0                                 6                               5
# 1                                 5                               5
# 2                                 3                               5
# 3                                 3                               5
# 4                                 6                               5
#
#    metadata.last_purchase.personalization  metadata.last_purchase.confidence  \
# 0                                       5                                  4
# 1                                       5                                  5
# 2                                       5                                  4
# 3                                       5                                  6
# 4                                       7                                  3
#
#    metadata.user.veracity  metadata.user.grounding  metadata.user.clarity  \
# 0                       6                        6                      5
# 1                       6                        5                      5
# 2                       5                        5                      5
# 3                       6                        6                      5
# 4                       6                        6                      5
#
#    metadata.user.personalization  metadata.user.confidence
# 0                              7                         4
# 1                              5                         5
# 2                              5                         6
# 3                              5                         4
# 4                              5                         4
